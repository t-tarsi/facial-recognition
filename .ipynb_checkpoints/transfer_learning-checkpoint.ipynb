# %%
import os, shutil
from tqdm import tqdm
 
original_dataset_dir = 'CroppedYale'
 
# create a new directory for the subset of cat and dog images
base_dir = 'data'
 
# create base training, validation and test directories
def join_create_dir(base, suffix):
    """
    Join a base directory with a new folder name, creating the new
    directory and returning its path.
   
    :param base: base directory path
    :param suffix: folder to append
    """
    new_dir = os.path.join(base, suffix)
    os.mkdir(new_dir)
    return new_dir
train_dir = join_create_dir(base_dir, 'train')
validation_dir = join_create_dir(base_dir, 'validation')
test_dir = join_create_dir(base_dir, 'test')
 

# stratify these directories for cats and dogs

def split_people(base):
    """
    Stratifies a base directory into subdirectories for cats and dogs.
   
    :param base: base directory for which to create subdirectories
    """
    for i in range(1, 39):
        person_dir = os.path.join(base, 'person' + str(i))
        os.mkdir(person_dir)
   
    return person_dir
split_people(train_dir)
split_people(test_dir)
split_people(validation_dir)
 
def move_files(person, min, max, datatype):
    """
    Move a subset of images into the relavant subdir for cats or dogs.
   
    :param animal: cat or dog
    :param min: min image index
    :param max: max immage index
    :param datatype: train, validation or test set
    """
   
    fnames = ['{}-{}.jpg'.format(person, i) for i in range(min, max)]
    pbar = tqdm(range(min, max), desc=f'copying {person}s')
    for fname in fnames:
        src = os.path.join(original_dataset_dir, fname)
        dst = os.path.join(f'data/{datatype}/{person}/', fname)
        shutil.copyfile(src, dst)
        pbar.update()
    pbar.close()
 
 
for i in range(1, 39):
    move_files('person' + str(i), 1, 31, 'train')
    move_files('person' + str(i), 31, 41, 'validation')
    move_files('person' + str(i), 41, 50, 'test')
# Out:
# copying person1s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person1s: 100%|██████████| 30/30 [00:00<00:00, 1076.85it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person1s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person1s: 100%|██████████| 10/10 [00:00<00:00, 1291.51it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person1s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person1s: 100%|██████████| 9/9 [00:00<00:00, 1140.82it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person2s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person2s: 100%|██████████| 30/30 [00:00<00:00, 1242.58it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person2s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person2s: 100%|██████████| 10/10 [00:00<00:00, 1208.18it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person2s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person2s: 100%|██████████| 9/9 [00:00<00:00, 833.10it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person3s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person3s: 100%|██████████| 30/30 [00:00<00:00, 810.46it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person3s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person3s: 100%|██████████| 10/10 [00:00<00:00, 1172.48it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person3s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person3s: 100%|██████████| 9/9 [00:00<00:00, 1105.70it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person4s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person4s: 100%|██████████| 30/30 [00:00<00:00, 1351.77it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person4s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person4s: 100%|██████████| 10/10 [00:00<00:00, 1286.99it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person4s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person4s: 100%|██████████| 9/9 [00:00<00:00, 965.14it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person5s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person5s: 100%|██████████| 30/30 [00:00<00:00, 1676.65it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person5s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person5s: 100%|██████████| 10/10 [00:00<00:00, 1165.51it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person5s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person5s: 100%|██████████| 9/9 [00:00<00:00, 1102.28it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person6s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person6s: 100%|██████████| 30/30 [00:00<00:00, 1617.69it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person6s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person6s: 100%|██████████| 10/10 [00:00<00:00, 1154.47it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person6s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person6s: 100%|██████████| 9/9 [00:00<00:00, 1024.00it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person7s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person7s: 100%|██████████| 30/30 [00:00<00:00, 1860.36it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person7s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person7s: 100%|██████████| 10/10 [00:00<00:00, 1023.43it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person7s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person7s: 100%|██████████| 9/9 [00:00<00:00, 1090.94it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person8s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person8s: 100%|██████████| 30/30 [00:00<00:00, 1628.22it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person8s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person8s: 100%|██████████| 10/10 [00:00<00:00, 1140.78it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person8s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person8s: 100%|██████████| 9/9 [00:00<00:00, 1151.47it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person9s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person9s: 100%|██████████| 30/30 [00:00<00:00, 1627.78it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person9s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person9s: 100%|██████████| 10/10 [00:00<00:00, 1129.44it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person9s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person9s: 100%|██████████| 9/9 [00:00<00:00, 1058.81it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying
34it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person26s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person26s: 100%|██████████| 30/30 [00:00<00:00, 1621.26it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person26s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person26s: 100%|██████████| 10/10 [00:00<00:00, 1235.95it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person26s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person26s: 100%|██████████| 9/9 [00:00<00:00, 1021.45it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person27s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person27s: 100%|██████████| 30/30 [00:00<00:00, 1560.28it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person27s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person27s: 100%|██████████| 10/10 [00:00<00:00, 1233.47it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person27s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person27s: 100%|██████████| 9/9 [00:00<00:00, 1336.33it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person28s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person28s: 100%|██████████| 30/30 [00:00<00:00, 1603.84it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person28s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person28s: 100%|██████████| 10/10 [00:00<00:00, 1283.88it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person28s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person28s: 100%|██████████| 9/9 [00:00<00:00, 1220.14it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person29s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person29s: 100%|██████████| 30/30 [00:00<00:00, 1857.48it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person29s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person29s: 100%|██████████| 10/10 [00:00<00:00, 1279.26it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person29s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person29s: 100%|██████████| 9/9 [00:00<00:00, 1141.83it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person30s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person30s: 100%|██████████| 30/30 [00:00<00:00, 1697.02it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person30s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person30s: 100%|██████████| 10/10 [00:00<00:00, 1666.66it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person30s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person30s: 100%|██████████| 9/9 [00:00<00:00, 1503.22it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person31s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person31s: 100%|██████████| 30/30 [00:00<00:00, 1675.40it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person31s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person31s: 100%|██████████| 10/10 [00:00<00:00, 1558.58it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person31s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person31s: 100%|██████████| 9/9 [00:00<00:00, 1373.03it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person32s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person32s: 100%|██████████| 30/30 [00:00<00:00, 1708.31it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person32s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person32s: 100%|██████████| 10/10 [00:00<00:00, 1555.69it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person32s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person32s: 100%|██████████| 9/9 [00:00<00:00, 1172.36it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person33s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person33s: 100%|██████████| 30/30 [00:00<00:00, 1890.12it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person33s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person33s: 100%|██████████| 10/10 [00:00<00:00, 1245.49it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person33s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person33s: 100%|██████████| 9/9 [00:00<00:00, 1167.93it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person34s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person34s: 100%|██████████| 30/30 [00:00<00:00, 1540.76it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person34s:   0%|          | 0/10 [00:00<?, ?it/s]
# copying person34s: 100%|██████████| 10/10 [00:00<00:00, 1513.81it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person34s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person34s: 100%|██████████| 9/9 [00:00<00:00, 1273.14it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person35s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person35s: 100%|██████████| 30/30 [00:00<00:00, 1901.52it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person35s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person35s: 100%|██████████| 10/10 [00:00<00:00, 1136.64it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person35s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person35s: 100%|██████████| 9/9 [00:00<00:00, 1183.57it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person36s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person36s: 100%|██████████| 30/30 [00:00<00:00, 1726.12it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person36s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person36s: 100%|██████████| 10/10 [00:00<00:00, 1607.69it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person36s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person36s: 100%|██████████| 9/9 [00:00<00:00, 922.79it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person37s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person37s: 100%|██████████| 30/30 [00:00<00:00, 1614.64it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person37s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person37s: 100%|██████████| 10/10 [00:00<00:00, 1432.73it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person37s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person37s: 100%|██████████| 9/9 [00:00<00:00, 947.27it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person38s:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person38s: 100%|██████████| 30/30 [00:00<00:00, 1685.27it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person38s:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person38s: 100%|██████████| 10/10 [00:00<00:00, 1166.83it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person38s:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# copying person38s: 100%|██████████| 9/9 [00:00<00:00, 1421.10it/s]

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
            './data/train/',
            target_size=(168, 192),
            batch_size=3,
            class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
            './data/validation',
            target_size=(168, 192),
            batch_size=3,
            class_mode='categorical')
# Out:
# Found 1140 images belonging to 38 classes.
# Found 380 images belonging to 38 classes.

# %%
datagen = ImageDataGenerator(rescale=1./255)

generator = datagen.flow_from_directory(
    directory,
    target_size=(168, 192),
    batch_size=3,
    class_mode='categorical')

# %%
from keras.applications import inception_v3

conv_base = inception_v3.InceptionV3(weights='imagenet',
                                     include_top=False,
                                     input_shape=(168, 192, 3))
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 61s 1us/step

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Model)         (None, 3, 4, 2048)        21802784
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 24576)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               6291712
# _________________________________________________________________
# dense_2 (Dense)              (None, 38)                9766
# =================================================================
# Total params: 28,104,262
# Trainable params: 28,069,830
# Non-trainable params: 34,432
# _________________________________________________________________

# %%
conv_base.trainable = False

# %%
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm_notebook as tqdm

base_dir = '/Users/tylertarsi/Documents/ix/facial-recognition/data/'

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')
test_dir = os.path.join(base_dir, 'test')

datagen = ImageDataGenerator(rescale=1./255)
batch_size = 1

def extract_features(directory, sample_count):
    features = np.zeros(shape=(sample_count, 3, 4, 2048))
    labels = np.zeros(shape=(sample_count, 38))
    generator = datagen.flow_from_directory(
        directory,
        target_size=(168, 192),
        batch_size=batch_size,
        class_mode='categorical')
    i = 0
    pbar = tqdm(range(sample_count // batch_size))
    for inputs_batch, labels_batch in generator:
        # compute features for input images in batch
        features_batch = conv_base.predict(inputs_batch)
        # store the computed features and labels in larger Numpy arr
        print(features_batch.shape)
        features[i * batch_size : (i + 1) * batch_size] = features_batch
        labels[i * batch_size : (i + 1) * batch_size] = labels_batch
        i += 1
        if i * batch_size >= sample_count:
            # Note that since generators yield data indefinitely in a loop,
            # we must `break` after every image has been seen once.
            break
        pbar.update()
    pbar.close()
    return features, labels

train_features, train_labels = extract_features(train_dir, 30)
validation_features, validation_labels = extract_features(validation_dir, 10)
test_features, test_labels = extract_features(test_dir, 9)
# Out:
# Found 1140 images belonging to 38 classes.
# HBox(children=(IntProgress(value=0, max=30), HTML(value='')))
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# Found 380 images belonging to 38 classes.
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# Found 342 images belonging to 38 classes.
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)
# (1, 3, 4, 2048)

# %%
train_features = np.reshape(train_features, (30, 3 * 4 * 2048))
validation_features = np.reshape(validation_features, (10, 3 * 4 * 2048))
test_features = np.reshape(test_features, (9, 3 * 4 * 2048))

# %%
from keras import models
from keras import layers
from keras import optimizers

model = models.Sequential()
model.add(layers.Dense(2048, activation='relu', input_dim=3 * 4 * 2048))
model.add(layers.Dense(38, activation='sigmoid'))

model.compile(optimizer=optimizers.RMSprop(lr=2e-5),
              loss='categorical_crossentropy',
              metrics=['acc'])

history = model.fit(train_features, train_labels,
                    epochs=30,
                    batch_size=1,
                    validation_data=(validation_features, validation_labels))
# Out:
# Train on 30 samples, validate on 10 samples
# Epoch 1/30
# 30/30 [==============================] - 19s 635ms/step - loss: 4.0537 - acc: 0.1333 - val_loss: 4.8557 - val_acc: 0.1000
# Epoch 2/30
# 30/30 [==============================] - 16s 542ms/step - loss: 2.6665 - acc: 0.3333 - val_loss: 5.2112 - val_acc: 0.1000
# Epoch 3/30
# 30/30 [==============================] - 16s 548ms/step - loss: 2.1779 - acc: 0.4333 - val_loss: 6.0100 - val_acc: 0.1000
# Epoch 4/30
# 30/30 [==============================] - 17s 556ms/step - loss: 1.9589 - acc: 0.4333 - val_loss: 6.7064 - val_acc: 0.1000
# Epoch 5/30
# 30/30 [==============================] - 17s 551ms/step - loss: 1.6838 - acc: 0.3667 - val_loss: 7.1351 - val_acc: 0.1000
# Epoch 6/30
# 30/30 [==============================] - 17s 551ms/step - loss: 1.4223 - acc: 0.4000 - val_loss: 7.2664 - val_acc: 0.0000e+00
# Epoch 7/30
# 30/30 [==============================] - 17s 553ms/step - loss: 0.3852 - acc: 0.9000 - val_loss: 5.0463 - val_acc: 0.1000
# Epoch 8/30
# 30/30 [==============================] - 17s 555ms/step - loss: 0.2482 - acc: 0.9000 - val_loss: 6.0634 - val_acc: 0.1000
# Epoch 9/30
# 30/30 [==============================] - 17s 554ms/step - loss: 0.0443 - acc: 1.0000 - val_loss: 4.6016 - val_acc: 0.1000
# Epoch 10/30
# 30/30 [==============================] - 17s 577ms/step - loss: 0.0025 - acc: 1.0000 - val_loss: 4.6496 - val_acc: 0.1000
# Epoch 11/30
# 30/30 [==============================] - 17s 579ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 4.9041 - val_acc: 0.1000
# Epoch 12/30
# 30/30 [==============================] - 17s 579ms/step - loss: 3.8167e-04 - acc: 1.0000 - val_loss: 5.3605 - val_acc: 0.1000
# Epoch 13/30
# 30/30 [==============================] - 17s 565ms/step - loss: 1.9488e-04 - acc: 1.0000 - val_loss: 4.9946 - val_acc: 0.1000
# Epoch 14/30
# 30/30 [==============================] - 17s 576ms/step - loss: 0.0035 - acc: 1.0000 - val_loss: 5.3436 - val_acc: 0.1000
# Epoch 15/30
# 30/30 [==============================] - 17s 567ms/step - loss: 1.6553e-05 - acc: 1.0000 - val_loss: 5.3647 - val_acc: 0.1000
# Epoch 16/30
# 11/30 [==========>...................] - ETA: 10s - loss: 1.1244e-05 - acc: 1.0000
